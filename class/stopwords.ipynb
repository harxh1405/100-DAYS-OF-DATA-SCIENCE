# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: click in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from nltk) (4.67.1)

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
print("Total stopwords: ",len(stop_words))
print(stop_words)
# Out:
# Total stopwords:  198
# {'down', "we're", 'then', 'shouldn', "i'd", "she's", 'having', 'they', 'with', "didn't", "he's", 'against', 'does', "wouldn't", 'needn', 'into', 'because', "it's", "needn't", 'as', 'than', "they've", 'how', "you'd", 'few', "they'll", 'yours', 'do', 'doesn', 'below', "he'll", 'doing', "that'll", 'while', 'y', 'its', 'him', "we'll", 'some', 'd', 'too', 'once', 'weren', 'my', 'don', 'whom', 'on', 'mustn', 'ours', 'isn', 'aren', 'of', 'where', 'both', 'our', 'about', "shouldn't", 'not', 'such', 'to', 'an', 'their', 't', "he'd", 'just', "weren't", "she'll", 'so', 'yourselves', 'your', 'same', "you've", "don't", 'in', 'a', 'did', 'or', 'off', 'themselves', 'from', 'itself', 'until', 're', "couldn't", "they'd", 'she', 'who', 'above', 'only', 'he', 'again', 'at', "i'll", "i'm", "i've", 'and', 'have', 'for', 'didn', 'them', "wasn't", 'but', 'very', 'all', 'by', 'shan', "they're", 'up', "should've", "won't", "you'll", 'out', 'no', 'hadn', 'should', 'the', "she'd", "it'll", 'theirs', 've', "doesn't", "hadn't", 'any', "we'd", 'mightn', 'you', 'each', 'his', 'me', 'won', 'has', 'be', 'before', "aren't", 'her', 'it', 'those', 'will', 'herself', 'that', 'after', 'had', 'i', 'nor', 'other', 'over', "it'd", 'ourselves', 'yourself', "hasn't", 'these', 'is', 'wouldn', 'ma', 'can', 'now', 'haven', "shan't", "isn't", 'we', "we've", 's', 'll', 'between', 'why', 'been', 'when', 'couldn', 'are', 'most', 'which', 'am', "you're", 'were', 'through', "mustn't", 'what', 'himself', "haven't", 'was', 'being', 'there', 'under', 'wasn', 'this', 'm', 'further', 'more', 'ain', 'myself', 'hers', 'hasn', 'own', 'o', 'during', 'if', 'here', "mightn't"}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/harshsingh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
