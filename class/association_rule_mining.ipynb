# %%
# !pip install mlxtend
# Out:
# /opt/anaconda3/envs/campusx/lib/python3.12/pty.py:95: DeprecationWarning: This process (pid=5464) is multi-threaded, use of forkpty() may lead to deadlocks in the child.
#   pid, fd = os.forkpty()
# Requirement already satisfied: mlxtend in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (0.24.0)
# Requirement already satisfied: scipy>=1.16.3 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=2.3.5 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from mlxtend) (2.4.0)
# Requirement already satisfied: pandas>=2.3.3 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/anaconda3/envs/campusx/lib/python3.12/site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)

# %% [markdown]
# Market basket analysis

# %%
import pandas as pd
# from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
data={
    'Milk': [1, 0, 1, 1, 0],
    'Bread': [1, 1, 1, 0, 1],
    'Eggs': [0, 1, 1, 1, 0],
    'Diapers': [1, 1, 0, 1, 1],
    'Beer': [0, 1, 1, 0, 1]
}

# %%
df=pd.DataFrame(data)
df=df.astype(bool)
print(df)
frequent_itemsets=apriori(df, min_support=0.4, use_colnames=True)
print(frequent_itemsets)
rules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
print(rules)
# Out:
#     Milk  Bread   Eggs  Diapers   Beer
# 0   True   True  False     True  False
# 1  False   True   True     True   True
# 2   True   True   True    False   True
# 3   True  False   True     True  False
# 4  False   True  False     True   True
#     support                itemsets
# 0       0.6                  (Milk)
# 1       0.8                 (Bread)
# 2       0.6                  (Eggs)
# 3       0.8               (Diapers)
# 4       0.6                  (Beer)
# 5       0.4           (Milk, Bread)
# 6       0.4            (Milk, Eggs)
# 7       0.4         (Milk, Diapers)
# 8       0.4           (Eggs, Bread)
# 9       0.6        (Bread, Diapers)
# 10      0.6           (Beer, Bread)
# 11      0.4         (Eggs, Diapers)
# 12      0.4            (Eggs, Beer)
# 13      0.4         (Beer, Diapers)
# 14      0.4     (Eggs, Beer, Bread)
# 15      0.4  (Beer, Bread, Diapers)
#          antecedents       consequents  antecedent support  \
# 0             (Milk)           (Bread)                 0.6
# 1             (Milk)            (Eggs)                 0.6
# 2             (Eggs)            (Milk)                 0.6
# 3             (Milk)         (Diapers)                 0.6
# 4             (Eggs)           (Bread)                 0.6
# 5            (Bread)         (Diapers)                 0.8
# 6          (Diapers)           (Bread)                 0.8
# 7             (Beer)           (Bread)                 0.6
# 8            (Bread)            (Beer)                 0.8
# 9             (Eggs)         (Diapers)                 0.6
# 10            (Eggs)            (Beer)                 0.6
# 11            (Beer)            (Eggs)                 0.6
# 12            (Beer)         (Diapers)                 0.6
# 13      (Eggs, Beer)           (Bread)                 0.4
# 14     (Eggs, Bread)            (Beer)                 0.4
# 15     (Beer, Bread)            (Eggs)                 0.6
# 16            (Eggs)     (Beer, Bread)                 0.6
# 17            (Beer)     (Eggs, Bread)                 0.6
# 18     (Beer, Bread)         (Diapers)                 0.6
# 19   (Beer, Diapers)           (Bread)                 0.4
# 20  (Bread, Diapers)            (Beer)                 0.6
# 21            (Beer)  (Bread, Diapers)                 0.6
#
#     consequent support  support  confidence      lift  representativity  \
# 0                  0.8      0.4    0.666667  0.833333               1.0
# 1                  0.6      0.4    0.666667  1.111111               1.0
# 2                  0.6      0.4    0.666667  1.111111               1.0
# 3                  0.8      0.4    0.666667  0.833333               1.0
# 4                  0.8      0.4    0.666667  0.833333               1.0
# 5                  0.8      0.6    0.750000  0.937500               1.0
# 6                  0.8      0.6    0.750000  0.937500               1.0
# 7                  0.8      0.6    1.000000  1.250000               1.0
# 8                  0.6      0.6    0.750000  1.250000               1.0
# 9                  0.8      0.4    0.666667  0.833333               1.0
# 10                 0.6      0.4    0.666667  1.111111               1.0
# 11                 0.6      0.4    0.666667  1.111111               1.0
# 12                 0.8      0.4    0.666667  0.833333               1.0
# 13                 0.8      0.4    1.000000  1.250000               1.0
# 14                 0.6      0.4    1.000000  1.666667               1.0
# 15                 0.6      0.4    0.666667  1.111111               1.0
# 16                 0.6      0.4    0.666667  1.111111               1.0
# 17                 0.4      0.4    0.666667  1.666667               1.0
# 18                 0.8      0.4    0.666667  0.833333               1.0
# 19                 0.8      0.4    1.000000  1.250000               1.0
# 20                 0.6      0.4    0.666667  1.111111               1.0
# 21                 0.6      0.4    0.666667  1.111111               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0      -0.08         0.6      -0.333333  0.400000  -0.666667    0.583333
# 1       0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 2       0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 3      -0.08         0.6      -0.333333  0.400000  -0.666667    0.583333
# 4      -0.08         0.6      -0.333333  0.400000  -0.666667    0.583333
# 5      -0.04         0.8      -0.250000  0.600000  -0.250000    0.750000
# 6      -0.04         0.8      -0.250000  0.600000  -0.250000    0.750000
# 7       0.12         inf       0.500000  0.750000   1.000000    0.875000
# 8       0.12         1.6       1.000000  0.750000   0.375000    0.875000
# 9      -0.08         0.6      -0.333333  0.400000  -0.666667    0.583333
# 10      0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 11      0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 12     -0.08         0.6      -0.333333  0.400000  -0.666667    0.583333
# 13      0.08         inf       0.333333  0.500000   1.000000    0.750000
# 14      0.16         inf       0.666667  0.666667   1.000000    0.833333
# 15      0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 16      0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 17      0.16         1.8       1.000000  0.666667   0.444444    0.833333
# 18     -0.08         0.6      -0.333333  0.400000  -0.666667    0.583333
# 19      0.08         inf       0.333333  0.500000   1.000000    0.750000
# 20      0.04         1.2       0.250000  0.500000   0.166667    0.666667
# 21      0.04         1.2       0.250000  0.500000   0.166667    0.666667
