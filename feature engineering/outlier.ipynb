# %% [markdown]
# ##Minimum.Maximum,Median,Q1,Q3,IQR

# %%
import numpy as np

# %%
lst_marks=[45,32,96,44,11,39,67,89,99,74,86,92,46,33,13]
minimum,Q1,median,Q3,maximum=np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(11.0),
#  np.float64(36.0),
#  np.float64(46.0),
#  np.float64(87.5),
#  np.float64(99.0))

# %%
IQR=Q3-Q1
IQR
# Out:
# np.float64(51.5)

# %%
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
lower_bound,upper_bound
# Out:
# (np.float64(-41.25), np.float64(164.75))

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks=[-100,-200,45,32,96,44,11,39,67,89,99,74,86,92,46,33,13,1000,1200,1300]

# %%
sns.boxplot(lst_marks) ##clearly see outliers here
# Out:
# <Axes: >
