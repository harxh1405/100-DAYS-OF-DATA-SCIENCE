# %% [markdown]
# LOGISTIC REGRESSION FOR IMBALANCED DATASET

# %%
from collections import Counter
from sklearn.datasets import make_classification
from sklear.mo

# %%
X,y=make_classification(n_samples=10000, n_features=10, n_classes=2, weights=[0.99], random_state=42) ##weights=[0.99] means 1 category will have 99 times more data points than other

# %%
X
# Out:
# array([[ 1.1958601 ,  0.35738502, -0.66586226, ...,  2.08168408,
#          0.04126585, -0.25829761],
#        [ 0.82531352,  1.10945943, -0.32313556, ..., -0.17220012,
#          1.1503591 ,  0.14774397],
#        [-0.90671286, -0.59331416,  0.71071436, ...,  0.43447665,
#          0.4236775 ,  1.2513799 ],
#        ...,
#        [ 0.84146796, -0.59374928, -0.39167125, ...,  0.28933544,
#         -0.43435776, -1.27133487],
#        [ 1.08025182, -0.60776141, -0.48860471, ...,  0.29149633,
#          0.82797965, -1.06939928],
#        [-1.20533758, -1.71964714,  0.99435846, ..., -0.30581946,
#         -1.40572814, -0.70320688]], shape=(10000, 10))

# %%
Counter(y)
# Out:
# Counter({np.int64(0): 9847, np.int64(1): 153})

# %%
import seaborn as sns
import pandas as pd
sns.scatterplot(x=pd.DataFrame(X)[0],y=pd.DataFrame(X)[1], hue=y)import iimiiiIIikjj
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
##split the dataset into train and test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=30)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
###managing imbalanced dataset
